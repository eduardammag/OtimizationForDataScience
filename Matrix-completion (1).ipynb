# %% [markdown]
# <div hidden>
#
# % Some handy commands
# $
# \newcommand{\cupdot}{\mathbin{\mathaccent\cdot\cup}}
# \newcommand{\esp}{\mathbb{E}}
# \newcommand{\prob}{\mathbb{P}}
# \newcommand{\probn}{\mathbf{P}}
# \newcommand{\espn}{\mathbf{E}}
# \newcommand{\Var}{\mathbb{V}}
# \newcommand{\Cov}{\mathbb{Cov}}
# \DeclareMathOperator*{\diag}{Diag}
# \DeclareMathOperator*{\sign}{sign}
# \newcommand{\alg}{\mathcal{F}}
# \newcommand{\alge}{\mathcal{G}}
# \newcommand{\unit}{\mathbf{1}}
# \newcommand{\id}{\mathbf{I}}
# \newcommand{\re}{\mathbb{R}}
# \newcommand{\pc}{\mathfrak{p}}
# \newcommand{\qc}{\mathfrak{q}}
# \newcommand{\tr}{tr}
# \newcommand{\median}{\mathsf{median}}
# \newcommand{\KL}{KL}
# \DeclareMathOperator*{\op}{op}
# \DeclareMathOperator*{\dom}{dom}
# \DeclareMathOperator*{\diag}{diag}
# \DeclareMathOperator*{\rank}{rank}
# \DeclareMathOperator*{\vetor}{vec}
# \DeclareMathOperator*{\range}{\mathcal{R}}
# \newcommand{\set}[1]{\left\{#1\right\}}
# \DeclareMathOperator*{\diam}{diam}
# \newcommand{\Med}{\mathsf{Med}}
# \DeclareMathOperator*{\argmin}{argmin}
# \DeclareMathOperator*{\argmax}{argmax}
# \DeclareMathOperator*{\maxx}{max}
# $
#
# % Boldface letters
# $
# \def\bfDelta{\boldsymbol{\Delta}}
# \def\bfOmega{\bold{\Omega}}
# \def\bfGamma{\bold{\Gamma}}
# \def\bfSigma{\bold{\Sigma}}
# \def\bfTheta{\bold{\Theta}}
# \def\bfPsi{\bold{\Psi}}
# \def\bfXi{\bold{\Xi}}
# \def\bfA{\mathbf{A}}
# \def\bfB{\mathbf{B}}
# \def\bfC{\mathbf{C}}
# \def\bfD{\mathbf{D}}
# \def\bfE{\mathbf{E}}
# \def\bfF{\mathbf{F}}
# \def\bfH{\mathbf{H}}
# \def\bfI{\mathbf{I}}
# \def\bfM{\mathbf{M}}
# \def\bfL{\mathbf{L}}
# \def\bfP{\mathbf{P}}
# \def\bfQ{\mathbf{Q}}
# \def\bfR{\mathbf{R}}
# \def\bfU{\mathbf{U}}
# \def\bfV{\mathbf{V}}
# \def\bfW{\mathbf{W}}
# \def\bfX{\mathbf{X}}
# \def\bfY{\mathbf{Y}}
# \def\bfZ{\mathbf{Z}}
# \def\ba{\boldsymbol a}
# \def\bb{\boldsymbol b}
# \def\bc{\boldsymbol c}
# \def\be{\boldsymbol e}
# \def\bff{\boldsymbol f}
# \def\bg{\boldsymbol g}
# \def\bh{\boldsymbol h}
# \def\bx{\boldsymbol x}
# \def\by{\boldsymbol y}
# \def\bu{\boldsymbol u}
# \def\bv{\boldsymbol v}
# \def\bw{\boldsymbol w}
# \def\bz{\boldsymbol z}
# \def\bfzero{\mathbf{0}}
# \def\bbeta{\boldsymbol\beta}
# \def\bepsilon{\boldsymbol\epsilon}
# \def\bgamma{\boldsymbol\gamma}
# \def\bmu{\boldsymbol\mu}
# \def\bomega{\boldsymbol\omega}
# \def\brho{\boldsymbol\rho}
# \def\bsigma{\boldsymbol\sigma}
# \def\btheta{\boldsymbol\theta}
# \def\bxi{\boldsymbol{\xi}}
# \def\bvarpi{\boldsymbol\varpi}
# $
#
# %script letters
# $
# \def\calA{\mathcal A}
# \def\calB{\mathcal B}
# \def\calC{\mathcal C}
# \def\calD{\mathcal D}
# \def\calE{\mathcal E}
# \def\calF{\mathcal F}
# \def\calG{\mathcal G}
# \def\calI{\mathcal I}
# \def\calK{\mathcal K}
# \def\calJ{\mathcal J}
# \def\calL{\mathcal L}
# \def\calM{\mathcal M}
# \def\calN{\mathcal N}
# \def\calO{\mathcal O}
# \def\calP{\mathcal P}
# \def\calR{\mathcal R}
# \def\calS{\mathcal S}
# \def\calQ{\mathcal Q}
# \def\calU{\mathcal U}
# \def\calV{\mathcal V}
# \def\calX{\mathcal X}
# \def\calZ{\mathcal Z}
# $
#
# %mathfrak letters
# $
# \def\frA{\mathfrak{A}}
# \def\frC{\mathfrak{C}}
# \def\frD{\mathfrak{D}}
# \def\frH{\mathfrak{H}}
# \def\frM{\mathfrak{M}}
# \def\frS{\mathfrak{S}}
# \def\frU{\mathfrak{U}}
# \def\frX{\mathfrak{X}}
# \def\frZ{\mathfrak{Z}}
# \def\frm{\mathfrak{m}}
# $
#
# %mathbb letters
# $
# \def\mbA{\mathbb{A}}
# \def\mbB{\mathbb{B}}
# \def\mbC{\mathbb{C}}
# \def\mbS{\mathbb{S}}
# \def\mbN{\mathbb{N}}
# \def\mbX{\mathbb{X}}
# $
#
# %mathscr letters
# $
# \def\mcC{\mathscr{C}}
# \def\mcF{\mathscr{F}}
# \def\mcL{\mathscr{L}}
# \def\mcN{\mathscr{N}}
# \def\mcP{\mathscr{P}}
# \def\mcR{\mathscr{R}}
# \def\mcX{\mathscr{X}}
# $
#
# %\mathds letters
# $
# \def\mdC{\mathds{C}}
# \def\mdF{\mathds{F}}
# \def\mdR{\mathds{R}}
# $
#
# </div>

# %% [markdown]
# # Completação de matrizes (*Matrix Completion*)
#
# O objetivo deste projeto é implementar alguns métodos iterativos de otimização para o *completamento de matrizes*. Por exemplo, o problema de estimar as notas/avaliações faltantes de itens de consumo dadas por usuários (sabendo-se uma amostra pequena). O Netflix se utiliza de algoritmos deste tipo para sugerir filmes ao usuário. De fato, existe toda uma área chamada *Sistemas de Recomendação (Recommendation Systems)* que trata de problemas do tipo.
#
# <div>
# <img src="recommendation-system.png" width="500"/>
# </div>
#
# Para facilitar, iremos à seguir apresentar algumas definições. Denotaremos por $\bfX^*$ a matriz $n_1\times n_2$ não observada. As entradas observadas da matriz $\bfX^*$ correspondem aos índices:
# $$
# \Omega := \{(i,j):\text{ usuário } i \text{ avalia item } j\}.
# $$
#
# Definiremos o *operador de amostragem* $\calP_\Omega:\re^{n_1\times n_2}\rightarrow\re^{n_1\times n_2}$ que leva
# uma matriz $\bfA\in\re^{n_1\times n_2}$, à matriz
# $$
# \left(\calP_{\Omega}[\bfA]\right)_{i,j}=
# \begin{cases}
# \bfA_{i,j},& \text{ if } (i,j)\in\Omega,\\
# 0,& \text{ if } (i,j)\notin\Omega.
# \end{cases}
# $$
# A operação complementar é
# $$
# \left(\calP_{\Omega}^\perp[\bfA]\right)_{i,j}=
# \begin{cases}
# 0,& \text{ if } (i,j)\in\Omega,\\
# \bfA_{i,j},& \text{ if } (i,j)\notin\Omega.
# \end{cases}
# $$
# A matriz observada pode ser escrita como
# $$
# \bfY := \calP_{\Omega}[\bfX^*].
# $$
# Portanto, as entradas não observadas correspondem à zero na matriz $\bfY$.

# %% [markdown]
# # Soft-Thresholding
#
# Dado números $\alpha>0$ and $\gamma\in\re$,
# $$
# \calS_\alpha(\gamma):=\sign(\gamma)\cdot\max\{\gamma-\alpha,0\}.
# $$
# é chamado *soft-thresholding* de $\gamma$ com threshold $\alpha$. Àcima, $\sign(\gamma)$ é o sinal de $\gamma$.
#
# Seja uma matriz $\bfW$ com decomposição de valores singulares (SVD):
# $$
# \bfW = \bfU\cdot\bfD(\gamma_1,\ldots,\gamma_r)\cdot\bfV^\top.
# $$
# Então, para $\alpha>0$, definimos a matriz *soft-thresholding* de $\bfW$ com threshold $\alpha$ por
# $$
# \calS_\alpha(\bfW) := \bfU\cdot\bfD\left(\calS_\alpha(\gamma_1),\ldots,\calS_\alpha(\gamma_r)\right)\cdot\bfV^\top.
# $$

# %% [markdown]
# # Norma de Frobenius e norma nuclear
#
# Dada matrix $\bfX$, sua *norma de Frobenius* é dada por
# $$
# \Vert\bfX\Vert_F:=\sqrt{\sum_{i=1}^{n_1}\sum_{j=1}^{n_2}\bfX_{ij}^2}.
# $$
# A *norma nuclear* de $\bfX$ é dada por
# $$
# \Vert\bfX\Vert_N:=\sum_{i=1}^r\sigma_i(\bfX),
# $$
# onde $r$ é o posto de $\bfX$ e $\sigma_1(\bfX)>\cdots>\sigma_r(\bfX)$ são os valores singulares de $\bfX$.

# %% [markdown]
# # Exercício 1: Gerando dados
#
# Primeiro, construa a função ```data_genX(n,r,B_mag,m)``` que retorna 3 matrizes $n\times n$: (1) a matriz de dados $\bfX^*$ de posto $r$ e autovalores todos iguais a $B_{mag}$, (2) a matriz $\Omega$ contendo 1 se a entrada correspondente é observada e 0 caso contrário e (3) a matriz $\Omega^\perp$ contendo 0 se a entrada correspondente é observada e 1 caso contrário. Ao gerar $\bfX^*$, use a função ```scipy.stats.ortho_group``` para construir duas matrizes $\bfU$ e $\bfV$ aleatórias ortogonais de dimensões $n\times r$; retorne
# $\bfX^*=\bfU\cdot D(B_{mag},\ldots,B_{mag})\cdot\bfV^\top$. Ao construir $\Omega$, dado $m=1,\ldots,n^2$, selecione aleatoriamente as $m$ entradas de $\bfX^*$ observadas.

# %%
import numpy as np
from scipy.stats import ortho_group

def data_genX(n, r, B_mag, m):
    # Geração de duas matrizes ortogonais aleatórias U e V de dimensão n x r
    U = ortho_group.rvs(n)[:, :r]
    V = ortho_group.rvs(n)[:, :r]
    
    # Criação da matriz diagonal D com autovalores todos iguais a B_mag
    D = np.diag([B_mag] * r)
    
    # Construção da matriz de dados X^* de posto r
    X_star = U @ D @ V.T
    
    # Inicialização de Omega e Omega_perp
    Omega = np.zeros((n, n))
    Omega_perp = np.ones((n, n))
    
    # Seleção aleatória de m entradas observadas
    indices = np.random.choice(n*n, m, replace=False)
    Omega_flat = Omega.flatten()
    Omega_flat[indices] = 1
    Omega = Omega_flat.reshape(n, n)
    
    # Omega_perp é o complemento de Omega
    Omega_perp = 1 - Omega
    
    return X_star, Omega, Omega_perp

# %%
#Exemplo:
n=3
r=1
B_mag=1
m=2
data = data_genX(n,r,B_mag,m)
data
# Out:
# (array([[ 0.33064151, -0.11295703, -0.08504173],
#         [-0.69557997,  0.23763092,  0.17890471],
#         [ 0.5022454 , -0.17158205, -0.12917863]]),
#  array([[0., 1., 0.],
#         [0., 0., 1.],
#         [0., 0., 0.]]),
#  array([[1., 0., 1.],
#         [1., 1., 0.],
#         [1., 1., 1.]]))

# %% [markdown]
# # Exercício 2: Funções auxiliares
#
# 1. Construe uma função ```P_omega(X.Omega)``` cujas entradas são uma matriz $n\times n$ $\bfX$ e $\Omega$ e retorna a matriz $\calP_\Omega(\bfX)$.
# 2. Construe uma função ```soft(x,l)``` que toma dois números $x$ e $l$ retorna $\calS_{l}(x)$.
# 3. Construe uma função ```Frob_sq(A)``` que retorna o quadrado da norma de Frobenius da matriz $A$, isto é,
# $
# \Vert\bfA\Vert_F^2 := \sum_{i,j}A_{ij}^2.
# $

# %%
def P_omega(X, Omega):
    """
    Aplica o operador de amostragem P_omega sobre a matriz X.
    Retorna uma matriz onde as entradas fora de Omega são zeradas.
    """
    return X * Omega

# %%
#Exemplo:
P_omega(data[0],data[1])
# Out:
# array([[ 0.        , -0.11295703, -0.        ],
#        [-0.        ,  0.        ,  0.17890471],
#        [ 0.        , -0.        , -0.        ]])

# %%
def soft(x, l):
    """
    Aplica o operador de soft-thresholding sobre o valor x com limiar l.
    """
    return np.sign(x) * max(abs(x) - l, 0)

# %%
#Exemplo:
soft(10,2.1)
# Out:
# 7.9

# %%
# 3. Função Frob_sq(A)
def Frob_sq(A):
    """
    Retorna o quadrado da norma de Frobenius da matriz A.
    """
    return np.sum(A**2)

# %%
#Exemplo:
Frob_sq(data[0])
# Out:
# 0.9999999999999996

# %% [markdown]
# # Exercício 3: Regularized Matrix Completion (RMC)
#
# Iremos resolver estimar $\bfX^*$ usando um método iterativo que resolve o seguinte problema de otimização:
# \begin{align}
# \begin{array}{cc}
# \min_{\bfX}&\frac{1}{2}\Vert\bfX\Vert_F^2+\lambda\Vert\bfX\Vert_N\\
# \text{s.t.}&\calP_{\Omega}[\bfX] = \bfY.
# \end{array}
# \end{align}
#
# Escolhendo $\lambda,L>0$ e ponto inicial $\bfW^0$, o seguinte método resolve o problema àcima:
# \begin{align}
# \bfX^{k}&:= \calS_{\lambda}\left(\bfW^{k}\right),\\
# \bfW^{k+1}&:=\bfW^{k} - \frac{n}{L}\left[\calP_{\Omega}(\bfX^k)-\bfY\right]
# \end{align}
#
# Referência: (https://arxiv.org/abs/0810.3286)
#
# Para tanto, construa uma função ```SVT(l,L,X,Y,Omega,it)``` que toma números positivos $\lambda=l$ e $L$, as matrizes $\bfX^*$, $\bfY$, e $\Omega$ e um número de iterações escolhido e retorna os últimos iterados $(\bfX^{it},\bfW^{it})$ e a sequência de erros $\Vert \bfX^k-\bfX^*\Vert^2$.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Função para decomposição SVD com soft-thresholding
def soft_threshold_matrix(W, lmbda):
    """
    Aplica o operador de soft-thresholding à matriz W com limiar lmbda.
    """
    # Decomposição SVD
    U, s, Vt = np.linalg.svd(W, full_matrices=False)
    # Aplica soft-thresholding nos valores singulares
    s_threshold = np.array([soft(si, lmbda) for si in s])
    # Reconstrói a matriz com os valores singulares ajustados
    return U @ np.diag(s_threshold) @ Vt

# Função SVT para completar a matriz usando o método iterativo
def SVT(l, L, X_star, Y, Omega, it):
    """
    Resolve o problema de Matrix Completion usando Singular Value Thresholding (SVT).
    
    Argumentos:
    l -- valor de lambda para regularização
    L -- valor de L para atualização
    X_star -- matriz original X^*
    Y -- matriz observada Y = P_omega(X^*)
    Omega -- matriz que indica as entradas observadas
    it -- número de iterações
    
    Retorna:
    X_it -- último iterado X^k
    W_it -- último iterado W^k
    error_seq -- sequência de erros \Vert X^k - X^*\Vert^2
    """
    # Inicialização de W^0
    W = np.zeros_like(X_star)
    
    # Inicializa a sequência de erros
    error_seq = []
    
    # Dimensão da matriz
    n = X_star.shape[0]
    
    # Iterações
    for k in range(it):
        # Passo 1: Calcula X^k aplicando soft-thresholding à matriz W^k
        X_k = soft_threshold_matrix(W, l)
        
        # Passo 2: Atualiza W^{k+1}
        W = W - (n / L) * (P_omega(X_k, Omega) - Y)
        
        # Calcula o erro \Vert X^k - X^* \Vert^2 e armazena
        error = Frob_sq(X_k - X_star)
        error_seq.append(error)
    
    # Retorna o último iterado X^k, W^k e a sequência de erros
    return X_k, W, error_seq

# %%
#Exemplo:
X = data[0]
Omega = data[1]
Y = P_omega(X,Omega)
n = X.shape[0]
l = n/5
L = 5
it = 100

f1 = SVT(l,L,X,Y,Omega,it)
error_SVT = f1[2]

import matplotlib.pyplot as plt
plt.plot(error_SVT)
plt.show()

# %% [markdown]
# # Exercício 4: Stable Matrix Completion (SMC)
#
# Em seguida, iremos resolver estimar $\bfX^*$ usando um método iterativo que resolve o seguinte problema de otimização:
# \begin{align}
# \begin{array}{cc}
# \min_{\bfX}& \frac{1}{2}\Vert\bfY-\calP_{\Omega}[\bfX]\Vert_F^2+\lambda\Vert\bfX\Vert_N.
# \end{array}
# \end{align}
#
# Escolhendo $\lambda,L>0$ e ponto inicial $\bfW^0$, o seguinte método resolve o problema àcima:
# \begin{align*}
# \bfX^{k}&:= \calS_{\frac{\lambda}{L}}\left(\bfW^{k}\right),\\
# \bfW^{k+1}&:=\bfX^{k}-\frac{1}{L}\left[\calP_{\Omega}(\bfX^k)-\bfY\right].
# \end{align*}
#
# Referência: (https://optimization-online.org/2009/03/2268/)
#
# Para tanto, construa uma função ```PG(l,L,X,Y,Omega,it)``` que toma números positivos $\lambda=l$ e $L$, as matrizes $\bfX^*$, $\bfY$, e $\Omega$ e um número de iterações escolhido e retorna os últimos iterados $(\bfX^{it},\bfW^{it})$ e a sequência de erros $\Vert \bfX^k-\bfX^*\Vert^2$.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Função para soft-thresholding de uma matriz
def soft_threshold_matrix(W, lmbda):
    """
    Aplica o operador de soft-thresholding à matriz W com limiar lmbda.
    """
    # Decomposição SVD
    U, s, Vt = np.linalg.svd(W, full_matrices=False)
    # Aplica soft-thresholding nos valores singulares
    s_threshold = np.array([soft(si, lmbda) for si in s])
    # Reconstrói a matriz com os valores singulares ajustados
    return U @ np.diag(s_threshold) @ Vt

# Função PG para completar a matriz usando o método iterativo
def PG(l, L, X_star, Y, Omega, it):
    """
    Resolve o problema de Matrix Completion estável usando Proximal Gradient (PG).
    
    Argumentos:
    l -- valor de lambda para regularização
    L -- valor de L para atualização
    X_star -- matriz original X^*
    Y -- matriz observada Y = P_omega(X^*)
    Omega -- matriz que indica as entradas observadas
    it -- número de iterações
    
    Retorna:
    X_it -- último iterado X^k
    W_it -- último iterado W^k
    error_seq -- sequência de erros \Vert X^k - X^*\Vert^2
    """
    # Inicialização de W^0
    W = np.zeros_like(X_star)
    
    # Inicializa a sequência de erros
    error_seq = []
    
    # Iterações
    for k in range(it):
        # Passo 1: Calcula X^k aplicando soft-thresholding à matriz W^k
        X_k = soft_threshold_matrix(W, l / L)
        
        # Passo 2: Atualiza W^{k+1}
        W = X_k - (1 / L) * (P_omega(X_k, Omega) - Y)
        
        # Calcula o erro \Vert X^k - X^* \Vert^2 e armazena
        error = Frob_sq(X_k - X_star)
        error_seq.append(error)
    
    # Retorna o último iterado X^k, W^k e a sequência de erros
    return X_k, W, error_seq

# Exemplo de uso
X = data[0]
Omega = data[1]
Y = P_omega(X, Omega)
n = X.shape[0]
l = n / 100
L = 5
it = 100

# Chamada da função PG
f2 = PG(l, L, X, Y, Omega, it)
error_PG = f2[2]

# Plotando a sequência de erros
plt.plot(error_PG)
plt.xlabel('Iterações')
plt.ylabel('Erro $\Vert X^k - X^*\Vert^2$')
plt.title('Convergência do Método Proximal Gradient (PG)')
plt.show()

# %%
#Exemplo:
X = data[0]
Omega = data[1]
Y = P_omega(X,Omega)
n = X.shape[0]
l = n/100
L = 5
it = 100

f2 = PG(l,L,X,Y,Omega,it)
error_PG = f2[2]

import matplotlib.pyplot as plt
plt.plot(error_PG)
plt.show()

# %% [markdown]
# # Exercício 5: Accelerated SMC
#
# Em seguida, iremos resolver estimar $\bfX^*$ usando um método iterativo *com aceleração de Nesterov* que resolve SMC. Escolhendo $\lambda,L>0$, inicializações $\bfX^0=\bfX^1$ e $t_0=t_1=1$, o seguinte método resolve o problema àcima:
#
# \begin{align*}
# \bfZ^k &:= \bfX^k + \frac{t_{k-1}-1}{t_k}(\bfX^k-\bfX^{k-1}),\label{algo:APG1}\\
# \bfW^k &:= \bfZ^{k}-\frac{1}{L}\left[\calP_{\Omega}(\bfZ^k)-\bfY\right],\\
# \bfX^{k+1}&:= \calS_{\frac{\lambda}{L}}\left(\bfW^k\right),\\
# t_{k+1} &:= \frac{1+\sqrt{1+4t_k^2}}{2}.
# \end{align*}
#
# Referência: (https://optimization-online.org/2009/03/2268/)
#
# Construa uma função ```APG(l,L,X,Y,Omega,it)``` que toma números positivos $\lambda=l$ e $L$, as matrizes $\bfX^*$, $\bfY$, e $\Omega$ e um número de iterações escolhido e retorna os últimos iterados $(\bfX^{it},\bfW^{it})$ e a sequência de erros $\Vert \bfX^k-\bfX^*\Vert^2$.

# %%
# Função para soft-thresholding de uma matriz
def soft_threshold_matrix(W, lmbda):
    """
    Aplica o operador de soft-thresholding à matriz W com limiar lmbda.
    """
    # Decomposição SVD
    U, s, Vt = np.linalg.svd(W, full_matrices=False)
    # Aplica soft-thresholding nos valores singulares
    s_threshold = np.array([soft(si, lmbda) for si in s])
    # Reconstrói a matriz com os valores singulares ajustados
    return U @ np.diag(s_threshold) @ Vt

# Função APG para completar a matriz usando aceleração de Nesterov
def APG(l, L, X_star, Y, Omega, it):
    """
    Resolve o problema de Matrix Completion estável usando Proximal Gradient com aceleração de Nesterov (APG).
    
    Argumentos:
    l -- valor de lambda para regularização
    L -- valor de L para atualização
    X_star -- matriz original X^*
    Y -- matriz observada Y = P_omega(X^*)
    Omega -- matriz que indica as entradas observadas
    it -- número de iterações
    
    Retorna:
    X_it -- último iterado X^k
    W_it -- último iterado W^k
    error_seq -- sequência de erros \Vert X^k - X^*\Vert^2
    """
    # Inicialização
    X_k = np.zeros_like(X_star)  # X^0
    X_k_minus_1 = np.copy(X_k)   # X^{-1} = X^0
    t_k = 1
    t_k_minus_1 = 1
    
    # Inicializa a sequência de erros
    error_seq = []
    
    # Iterações
    for k in range(it):
        # Passo 1: Atualiza Z^k
        Z_k = X_k + ((t_k_minus_1 - 1) / t_k) * (X_k - X_k_minus_1)
        
        # Passo 2: Atualiza W^k
        W_k = Z_k - (1 / L) * (P_omega(Z_k, Omega) - Y)
        
        # Passo 3: Atualiza X^{k+1} aplicando soft-thresholding
        X_k_plus_1 = soft_threshold_matrix(W_k, l / L)
        
        # Passo 4: Atualiza t_{k+1}
        t_k_plus_1 = (1 + np.sqrt(1 + 4 * t_k**2)) / 2
        
        # Calcula o erro \Vert X^k - X^* \Vert^2 e armazena
        error = Frob_sq(X_k_plus_1 - X_star)
        error_seq.append(error)
        
        # Atualiza as variáveis para a próxima iteração
        X_k_minus_1 = X_k
        X_k = X_k_plus_1
        t_k_minus_1 = t_k
        t_k = t_k_plus_1
    
    # Retorna o último iterado X^k, W^k e a sequência de erros
    return X_k, W_k, error_seq

# %%
#Exemplo:
X = data[0]
Omega = data[1]
Y = P_omega(X,Omega)
n = X.shape[0]
l = n/100
L = 5
it = 100

f3 = APG(l,L,X,Y,Omega,it)
error_APG = f3[2]

import matplotlib.pyplot as plt
plt.plot(error_PG)
plt.show()

# %% [markdown]
# # Exercício 6: SOFT-IMPUTE
#
# Finalmente, iremos ver outro algoritmo iterativo cuja heurística é bem diferente dos métodos anteriores baseados num problema de otimização regularizado. A idéia aqui se baseia em *imputar* iterativamente a matriz observada. Escolhendo-se $\lambda>0$ e ponto inicial $\bfX^0=0$, iteramos:
# \begin{align*}
# \bfX^{k+1}:=\calS_{\lambda}\left(\bfY+\calP_{\Omega}^\perp(\bfX^{k})\right).
# \end{align*}
# Equivalentemente:
# \begin{align*}
# \bfW^k&:=\bfY+\calP_{\Omega}^\perp(\bfX^{k}),\\
# \bfX^{k+1}&:=\calS_{\lambda}\left(\bfW^k\right).
# \end{align*}
#
# Referência: (https://jmlr.org/papers/v11/mazumder10a.html)
#
# Construa uma função ```SImp(l,X,Y,Omega_perp,it)``` que toma número positivo $\lambda=l$, as matrizes $\bfX^*$, $\bfY$, e $\Omega^\perp$ e um número de iterações escolhido e retorna os últimos iterados $(\bfX^{it},\bfW^{it})$ e a sequência de erros $\Vert \bfX^k-\bfX^*\Vert^2$.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Função para aplicar a projeção em Omega^perp (complemento de Omega)
def P_omega_perp(X, Omega):
    """
    Aplica a projeção no complemento de Omega, ou seja, mantem as entradas não observadas.
    """
    return X * (1 - Omega)

# Função para SOFT-IMPUTE
def SImp(l, X_star, Y, Omega_perp, it):
    """
    Resolve o problema de imputação iterativa (SOFT-IMPUTE).
    
    Argumentos:
    l -- valor de lambda para regularização
    X_star -- matriz original X^*
    Y -- matriz observada Y = P_omega(X^*)
    Omega_perp -- projeção complemento de Omega (Omega^perp)
    it -- número de iterações
    
    Retorna:
    X_it -- último iterado X^k
    W_it -- último iterado W^k
    error_seq -- sequência de erros \Vert X^k - X^*\Vert^2
    """
    # Inicialização
    X_k = np.zeros_like(X_star)  # X^0 = 0
    
    # Inicializa a sequência de erros
    error_seq = []
    
    # Iterações
    for k in range(it):
        # Passo 1: Atualiza W^k
        W_k = Y + P_omega_perp(X_k, Omega_perp)
        
        # Passo 2: Atualiza X^{k+1} aplicando soft-thresholding
        X_k_plus_1 = soft_threshold_matrix(W_k, l)
        
        # Calcula o erro \Vert X^k - X^* \Vert^2 e armazena
        error = Frob_sq(X_k_plus_1 - X_star)
        error_seq.append(error)
        
        # Atualiza a variável X_k para a próxima iteração
        X_k = X_k_plus_1
    
    # Retorna o último iterado X^k, W^k e a sequência de erros
    return X_k, W_k, error_seq

# Exemplo de uso
X = data[0]
Omega = data[1]
Omega_perp = data[2]
Y = P_omega(X, Omega)
n = X.shape[0]
l = n / 100
it = 100

# Chamada da função SImp
f4 = SImp(l, X, Y, Omega_perp, it)
error_SImp = f4[2]

# Plotando a sequência de erros
plt.plot(error_SImp)
plt.xlabel('Iterações')
plt.ylabel('Erro $\Vert X^k - X^*\Vert^2$')
plt.title('Convergência do Método SOFT-IMPUTE')
plt.show()

# %%
#Exemplo:
X = data[0]
Omega = data[1]
Omega_perp = data[2]
Y = P_omega(X,Omega)
n = X.shape[0]
l = n/100
it = 100

f4 = SImp(l,X,Y,Omega_perp,it)
error_SImp = f4[2]

import matplotlib.pyplot as plt
plt.plot(error_PG)
plt.show()

# %% [markdown]
# # Exercício 7: Plots
#
# Implemente num mesmo gráfico os erros quadráticos de cada método em função no número de iterações com os seguintes parâmetros:
# ``n=10
#   r=1
#   B_mag=1
#   m = 10*n*r``
#
# e:
#
# 1. SVT: ```l = n/5, L = 5, it = 100```
# 2. PG: ```l = n/100, L = 5, it = 100```
# 3. APG: ```l = n/100, L = 5, it = 100```
# 4. SImp: ```l = n/100, it = 100```

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assumindo que todas as funções SVT, PG, APG, SImp e P_omega foram implementadas corretamente.

# Parâmetros
n = 10
r = 1
B_mag = 1
m = 10 * n * r

# Criar matriz X^* e projeção Omega
X_star = np.random.randn(n, n)  # Matriz n x n aleatória
Omega = np.random.choice([0, 1], size=(n, n), p=[1 - m/(n*n), m/(n*n)])  # Projeção Omega
Omega_perp = 1 - Omega  # Complemento de Omega
Y = P_omega(X_star, Omega)  # Matriz observada

# Parâmetros de cada método
l_SVT = n / 5
L_SVT = 5
l_PG = n / 100
L_PG = 5
l_APG = n / 100
L_APG = 5
l_SImp = n / 100
iterations = 100

# Executar SVT
f_SVT = SVT(l_SVT, L_SVT, X_star, Y, Omega, iterations)
error_SVT = f_SVT[2]

# Executar PG
f_PG = PG(l_PG, L_PG, X_star, Y, Omega, iterations)
error_PG = f_PG[2]

# Executar APG
f_APG = APG(l_APG, L_APG, X_star, Y, Omega, iterations)
error_APG = f_APG[2]

# Executar SImp
f_SImp = SImp(l_SImp, X_star, Y, Omega_perp, iterations)
error_SImp = f_SImp[2]

# Plotar erros de cada método
plt.plot(error_SVT, label="SVT")
plt.plot(error_PG, label="PG")
plt.plot(error_APG, label="APG")
plt.plot(error_SImp, label="SImp")

plt.xlabel('Iterações')
plt.ylabel('Erro $\Vert X^k - X^*\Vert^2$')
plt.title('Comparação de Erros Quadráticos por Iteração')
plt.legend()
plt.grid(True)
plt.show()
